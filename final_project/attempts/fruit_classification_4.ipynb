# %% [markdown]
# # Fruit Classification CNN

# %%
import torch
import numpy as np

# check if CUDA is available
train_on_gpu = torch.cuda.is_available()

if not train_on_gpu:
    print('CUDA is not available.  Training on CPU ...')
else:
    print('CUDA is available!  Training on GPU ...')
# Out:
# CUDA is available!  Training on GPU ...

# %%
# Organizing the classes correctly
import pandas as pd
folder_to_class = {}
test_df = pd.read_csv('Fruit_dataset/test.csv')
val_df = pd.read_csv('Fruit_dataset/val.csv')

val_classes = ['']
test_classes = ['']

for i in range(len(test_df)):
    folder_loc = test_df.iloc[i]['image:FILE'].split('/')[1]
    if not folder_loc: break
    if folder_loc != test_classes[-1]:
        test_classes.append(folder_loc)
        
for i in range(len(val_df)):
    folder_loc = val_df.iloc[i]['image:FILE'].split('/')[1]
    if folder_loc != val_classes[-1]:
        val_classes.append(folder_loc)

val_classes = val_classes[1:]
test_classes = test_classes[1:]
folder_to_class = dict(zip(val_classes, test_classes))

print(folder_to_class)
# Out:
# {'oil_palm': '28', 'hog_plum': '3', 'apricot': '93', 'sugar_apple': '58', 'rambutan': '80', 'yellow_plum': '49', 'pineapple': '43', 'dewberry': '71', 'plumcot': '23', 'ambarella': '8', 'grenadilla': '46', 'elderberry': '98', 'barbadine': '87', 'horned_melon': '39', 'chico': '61', 'mock_strawberry': '92', 'cashew': '44', 'finger_lime': '9', 'apple': '12', 'eggplant': '38', 'pawpaw': '0', 'chokeberry': '55', 'jamaica_cherry': '18', 'grapefruit': '88', 'santol': '86', 'chenet': '95', 'salak': '1', 'indian_strawberry': '16', 'cherimoya': '47', 'otaheite_apple': '7', 'dragonfruit': '15', 'raspberry': '27', 'mangosteen': '63', 'yali_pear': '60', 'taxus_baccata': '76', 'coconut': '19', 'guava': '41', 'black_mullberry': '83', 'durian': '73', 'ackee': '2', 'olive': '26', 'mandarine': '70', 'black_berry': '29', 'acerola': '32', 'jaboticaba': '24', 'fig': '82', 'langsat': '78', 'redcurrant': '77', 'gooseberry': '13', 'camu_camu': '11', 'barberry': '69', 'rose_hip': '67', 'jalapeno': '65', 'brazil_nut': '89', 'damson': '31', 'acai': '53', 'prikly_pear': '37', 'morinda': '59', 'sea_buckthorn': '74', 'avocado': '40', 'strawberry_guava': '96', 'jackfruit': '20', 'greengage': '36', 'cupuacu': '5', 'longan': '68', 'passion_fruit': '91', 'feijoa': '97', 'betel_nut': '22', 'kaffir_lime': '81', 'sapodilla': '45', 'cempedak': '17', 'hawthorn': '57', 'mango': '21', 'malay_apple': '52', 'cranberry': '34', 'jocote': '84', 'cluster_fig': '66', 'corn_kernel': '6', 'kumquat': '99', 'rose_leaf_bramble': '54', 'jujube': '35', 'grape': '33', 'pea': '56', 'papaya': '14', 'bitter_gourd': '48', 'ugli_fruit': '64', 'jambul': '10', 'mabolo': '85', 'abiu': '62', 'quince': '90', 'custard_apple': '75', 'medlar': '72', 'mountain_soursop': '42', 'banana': '79', 'goumi': '51', 'hard_kiwi': '94', 'pomegranate': '25', 'white_currant': '30', 'lablab': '4', 'emblic': '50'}

# %%
import os
# from PIL import Image

# root_dir = 'Fruit_dataset/train1'

# max_width, max_height = float(0), float(0)
# min_width, min_height = float('inf'), float('inf')

# for subdir, _, files in os.walk(root_dir):
#     for file in files:
#         if file.lower().endswith(('.png', '.jpg', '.jpeg')):
#             img_path = os.path.join(subdir, file)
#             with Image.open(img_path) as img:
#                 w, h = img.size
#                 if w > max_width:
#                     max_width = w
#                 if h > max_height:
#                     max_height = h
#                 if w < min_width:
#                     min_width = w
#                 if h < min_height:
#                     min_height = h

# print(f"Smallest width: {min_width}, Smallest height: {min_height}")
# print(f"Biggest width: {max_width}, Biggest height: {max_height}")
test_path = "./Fruit_dataset/test1"

# List all subfolders (classes)
class_folders = [name for name in os.listdir(test_path) if os.path.isdir(os.path.join(test_path, name))]

print(f"Number of classes: {len(class_folders)}")
# Out:
# Number of classes: 100

# %%
from torchvision import datasets, transforms

from torchvision.datasets import ImageFolder

class MappedImageFolder(ImageFolder):
    def __init__(self, root, correct_order, transform=None):
        super().__init__(root, transform=transform)
        self.folder_to_label = {folder: correct_order.index(folder) for folder in self.classes}
        
    def __getitem__(self, index):
        path, _ = self.samples[index]
        image = self.loader(path)
        if self.transform is not None:
            image = self.transform(image)
        
        folder_name = path.split(os.sep)[-2]
        label = self.folder_to_label[folder_name]
        
        return image, label

batch_size = 100

train_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomVerticalFlip(p=0.3),
    transforms.RandomRotation(degrees=30),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    # transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])

transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    # transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])

# train_data = datasets.ImageFolder(root='Fruit_dataset/train1', transform=train_transform)
train_data = MappedImageFolder('Fruit_dataset/train1', val_classes, transform=train_transform)
train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, shuffle=True, pin_memory=True)
folder_to_correct_label = {folder: val_classes.index(folder) for folder in train_data.classes}
print(train_loader.dataset.classes)
print(folder_to_correct_label)

# val_data = datasets.ImageFolder(root='Fruit_dataset/val1', transform=transform)
val_data = MappedImageFolder('Fruit_dataset/val1', val_classes, transform=transform)
val_loader = torch.utils.data.DataLoader(val_data, batch_size=batch_size, shuffle=True, pin_memory=True)
folder_to_correct_label = {folder: val_classes.index(folder) for folder in val_data.classes}
print(len(val_data))

# test_data = datasets.ImageFolder(root='Fruit_dataset/test1', transform=transform)
test_data = MappedImageFolder('Fruit_dataset/test1', test_classes, transform=transform)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=batch_size, shuffle=True, pin_memory=True)
folder_to_correct_label = {folder: test_classes.index(folder) for folder in test_data.classes}
print(len(test_data))

# train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, shuffle=True)
# val_loader = torch.utils.data.DataLoader(val_data, batch_size=batch_size, shuffle=True)
# test_loader = torch.utils.data.DataLoader(test_data, batch_size=batch_size, shuffle=True)
# Out:
# ['abiu', 'acai', 'acerola', 'ackee', 'ambarella', 'apple', 'apricot', 'avocado', 'banana', 'barbadine', 'barberry', 'betel_nut', 'bitter_gourd', 'black_berry', 'black_mullberry', 'brazil_nut', 'camu_camu', 'cashew', 'cempedak', 'chenet', 'cherimoya', 'chico', 'chokeberry', 'cluster_fig', 'coconut', 'corn_kernel', 'cranberry', 'cupuacu', 'custard_apple', 'damson', 'dewberry', 'dragonfruit', 'durian', 'eggplant', 'elderberry', 'emblic', 'feijoa', 'fig', 'finger_lime', 'gooseberry', 'goumi', 'grape', 'grapefruit', 'greengage', 'grenadilla', 'guava', 'hard_kiwi', 'hawthorn', 'hog_plum', 'horned_melon', 'indian_strawberry', 'jaboticaba', 'jackfruit', 'jalapeno', 'jamaica_cherry', 'jambul', 'jocote', 'jujube', 'kaffir_lime', 'kumquat', 'lablab', 'langsat', 'longan', 'mabolo', 'malay_apple', 'mandarine', 'mango', 'mangosteen', 'medlar', 'mock_strawberry', 'morinda', 'mountain_soursop', 'oil_palm', 'olive', 'otaheite_apple', 'papaya', 'passion_fruit', 'pawpaw', 'pea', 'pineapple', 'plumcot', 'pomegranate', 'prikly_pear', 'quince', 'rambutan', 'raspberry', 'redcurrant', 'rose_hip', 'rose_leaf_bramble', 'salak', 'santol', 'sapodilla', 'sea_buckthorn', 'strawberry_guava', 'sugar_apple', 'taxus_baccata', 'ugli_fruit', 'white_currant', 'yali_pear', 'yellow_plum']
# {'abiu': 88, 'acai': 55, 'acerola': 43, 'ackee': 39, 'ambarella': 9, 'apple': 18, 'apricot': 2, 'avocado': 59, 'banana': 93, 'barbadine': 12, 'barberry': 50, 'betel_nut': 67, 'bitter_gourd': 84, 'black_berry': 42, 'black_mullberry': 37, 'brazil_nut': 53, 'camu_camu': 49, 'cashew': 16, 'cempedak': 70, 'chenet': 25, 'cherimoya': 28, 'chico': 14, 'chokeberry': 21, 'cluster_fig': 76, 'coconut': 35, 'corn_kernel': 77, 'cranberry': 74, 'cupuacu': 63, 'custard_apple': 90, 'damson': 54, 'dewberry': 7, 'dragonfruit': 30, 'durian': 38, 'eggplant': 19, 'elderberry': 11, 'emblic': 99, 'feijoa': 66, 'fig': 45, 'finger_lime': 17, 'gooseberry': 48, 'goumi': 94, 'grape': 81, 'grapefruit': 23, 'greengage': 62, 'grenadilla': 10, 'guava': 36, 'hard_kiwi': 95, 'hawthorn': 71, 'hog_plum': 1, 'horned_melon': 13, 'indian_strawberry': 27, 'jaboticaba': 44, 'jackfruit': 61, 'jalapeno': 52, 'jamaica_cherry': 22, 'jambul': 86, 'jocote': 75, 'jujube': 80, 'kaffir_lime': 68, 'kumquat': 78, 'lablab': 98, 'langsat': 46, 'longan': 64, 'mabolo': 87, 'malay_apple': 73, 'mandarine': 41, 'mango': 72, 'mangosteen': 32, 'medlar': 91, 'mock_strawberry': 15, 'morinda': 57, 'mountain_soursop': 92, 'oil_palm': 0, 'olive': 40, 'otaheite_apple': 29, 'papaya': 83, 'passion_fruit': 65, 'pawpaw': 20, 'pea': 82, 'pineapple': 6, 'plumcot': 8, 'pomegranate': 96, 'prikly_pear': 56, 'quince': 89, 'rambutan': 4, 'raspberry': 31, 'redcurrant': 47, 'rose_hip': 51, 'rose_leaf_bramble': 79, 'salak': 26, 'santol': 24, 'sapodilla': 69, 'sea_buckthorn': 58, 'strawberry_guava': 60, 'sugar_apple': 3, 'taxus_baccata': 34, 'ugli_fruit': 85, 'white_currant': 97, 'yali_pear': 33, 'yellow_plum': 5}
# 5000
# 5000

# %%
import matplotlib.pyplot as plt

def imshow(img):
  img = img / 2 + 0.5
  plt.imshow(np.transpose(img, (1, 2, 0)))

# %%
classes = train_data.classes

dataiter = iter(train_loader)

images, labels = next(dataiter)
images = images.numpy() # convert images to numpy for display

images, labels = next(dataiter)

fig = plt.figure(figsize=(12, 6))
for idx in range(8):
  ax = fig.add_subplot(2, 4, idx+1, xticks=[], yticks=[])
  imshow(images[idx])
  ax.set_title(classes[labels[idx]])

# from PIL import Image
# import matplotlib.pyplot as plt
# import os

# # Get a list of image file paths
# image_paths = []
# for subdir, _, files in os.walk('Fruit_dataset/train1'):
#     for file in files:
#         if file.lower().endswith(('.png', '.jpg', '.jpeg')):
#             image_paths.append(os.path.join(subdir, file))

# # Display the first 8 images
# fig = plt.figure(figsize=(12, 6))
# for idx, img_path in enumerate(image_paths[:8]):
#     img = Image.open(img_path)
#     ax = fig.add_subplot(2, 4, idx+1, xticks=[], yticks=[])
#     plt.imshow(img)
#     ax.set_title(os.path.basename(os.path.dirname(img_path)))
# plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.5418272..1.6195644].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.558952..1.7067103].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.558952..1.82].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.5247024..1.2884097].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.5418272..1.82].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.558952..1.6244541].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.558952..1.82].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.558952..1.6792717].

# %%
# import torch.nn as nn
# import torch.nn.functional as F

# class Net(nn.Module):
#     def __init__(self):
#         super(Net, self).__init__()
#         self.conv1 = nn.Conv2d(3, 32, kernel_size=3, padding=1)
#         self.bn1 = nn.BatchNorm2d(32)

#         self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
#         self.bn2 = nn.BatchNorm2d(64)

#         # self.conv3 = nn.Conv2d(64, 64, kernel_size=3, padding=1)
#         # self.bn3 = nn.BatchNorm2d(64)

#         self.conv3 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
#         self.bn3 = nn.BatchNorm2d(128)

#         # self.conv5 = nn.Conv2d(128, 128, kernel_size=3, padding=1)
#         # self.bn5 = nn.BatchNorm2d(128)

#         # self.conv6 = nn.Conv2d(128, 128, kernel_size=3, padding=1)
#         # self.bn6 = nn.BatchNorm2d(128)

#         self.conv4 = nn.Conv2d(128, 256, kernel_size=3, padding=1)
#         self.bn4 = nn.BatchNorm2d(256)
        
#         # self.conv8 = nn.Conv2d(256, 256, kernel_size=3, padding=1)
#         # self.bn8 = nn.BatchNorm2d(256)

#         # self.conv9 = nn.Conv2d(256, 256, kernel_size=3, padding=1)
#         # self.bn9 = nn.BatchNorm2d(256)

#         self.conv5 = nn.Conv2d(256, 512, kernel_size=3, padding=1)
#         self.bn5 = nn.BatchNorm2d(512)

#         # self.conv11 = nn.Conv2d(512, 512, kernel_size=3, padding=1)
#         # self.bn11 = nn.BatchNorm2d(512)

#         # self.conv12 = nn.Conv2d(512, 512, kernel_size=3, padding=1)
#         # self.bn12 = nn.BatchNorm2d(512)

#         # self.conv13 = nn.Conv2d(512, 1024, kernel_size=3, padding=1)
#         # self.bn13 = nn.BatchNorm2d(1024)

#         # self.conv14 = nn.Conv2d(1024, 1024, kernel_size=3, padding=1)
#         # self.bn14 = nn.BatchNorm2d(1024)

#         self.pool = nn.MaxPool2d(kernel_size=2, stride=2)

#         self.fc1 = nn.Linear(512 * 14 * 14, 512)
#         self.fc2 = nn.Linear(512, 256)
#         self.fc3 = nn.Linear(256, 100)

#         self.dropout = nn.Dropout(0.2)

#     def forward(self, x):
#         x = self.bn1(F.relu(self.conv1(x)))

#         x = self.pool(x)
        
#         x = self.bn2(F.relu(self.conv2(x)))
#         # x = self.bn3(F.relu(self.conv3(x)))

#         x = self.pool(x)

#         x = self.bn3(F.relu(self.conv3(x)))
#         # x = self.bn5(F.relu(self.conv5(x)))
#         # x = self.bn6(F.relu(self.conv6(x)))

#         x = self.pool(x)

#         x = self.bn4(F.relu(self.conv4(x)))
#         # x = self.bn8(F.relu(self.conv8(x)))
#         # x = self.bn9(F.relu(self.conv9(x)))

#         x = self.pool(x)

#         x = self.bn5(F.relu(self.conv5(x)))
#         # x = self.bn11(F.relu(self.conv11(x)))
#         # x = self.bn12(F.relu(self.conv12(x)))

#         # x = self.pool(x)

#         # x = self.bn13(F.relu(self.conv13(x)))
#         # x = self.bn14(F.relu(self.conv14(x)))

#         # x = x.view(-1, 256 * 14 * 14)
#         x = x.view(x.size(0), -1)

#         x = F.relu(self.fc1(x))
#         x = F.relu(self.fc2(x))
#         x = self.fc3(x)
#         return x
    
# model = Net()
# print(model)

# if(train_on_gpu):
#   model.cuda()

# %%
import torch.nn as nn
import torch.nn.functional as F

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()

        num_blocks = 4
        num_params = 32
        # img_size = 224

        self.blocks = nn.ModuleList()

        for idx in range(num_blocks):
            if idx == 0:
                self.blocks.append(
                    nn.Conv2d(3, num_params, kernel_size=3, stride=1, padding=1)
                )
            else:
                num_params *= 2
                self.blocks.append(
                    nn.Conv2d(int(num_params / 2), num_params, kernel_size=3, stride=1, padding=1)
                )

            self.blocks.append(
                    nn.Conv2d(num_params, num_params, kernel_size=3, stride=1, padding=1)
            )
            self.blocks.append(nn.BatchNorm2d(num_params))
            self.blocks.append(nn.ReLU())
            if idx < num_blocks - 1:
                self.blocks.append(nn.MaxPool2d(2, 2))
                # img_size //= 2
            else:
                self.blocks.append(nn.AdaptiveAvgPool2d((2, 2)))

            self.blocks.append(nn.ReLU())


        self.fc1 = nn.Linear(num_params * 2 * 2, 1024)
        self.fc2 = nn.Linear(1024, 512)
        self.fc3 = nn.Linear(512, len(classes))

        self.dropout = nn.Dropout(0.5)

    def forward(self, x):
        for block in self.blocks:
            x = block(x)

        x = x.view(x.size(0), -1)
        x = F.relu(self.fc1(x))
        x = self.dropout(x)
        x = F.relu(self.fc2(x))
        x = self.fc3(x)

        return x





model = Net()
print(model)

if(train_on_gpu):
  model.cuda()
# Out:
# Net(
#   (blocks): ModuleList(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): ReLU()
#     (6): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): ReLU()
#     (10): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (11): ReLU()
#     (12): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (14): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (15): ReLU()
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): ReLU()
#     (18): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (19): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (21): ReLU()
#     (22): AdaptiveAvgPool2d(output_size=(2, 2))
#     (23): ReLU()
#   )
#   (fc1): Linear(in_features=1024, out_features=1024, bias=True)
#   (fc2): Linear(in_features=1024, out_features=512, bias=True)
#   (fc3): Linear(in_features=512, out_features=100, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
# )

# %%
import torch.optim as optim
from torch.amp import autocast, GradScaler
criterion = nn.CrossEntropyLoss()

optimizer = optim.Adam(model.parameters(), lr=0.001)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=20, gamma=0.7)
scaler = GradScaler('cuda' if train_on_gpu else 'cpu')

# %%
def calculate_accuracy(model, dataloader, device):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for inputs, labels in dataloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    return correct / total

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# Net(
#   (blocks): ModuleList(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): ReLU()
#     (6): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): ReLU()
#     (10): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (11): ReLU()
#     (12): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (14): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (15): ReLU()
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): ReLU()
#     (18): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (19): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (21): ReLU()
#     (22): AdaptiveAvgPool2d(output_size=(2, 2))
#     (23): ReLU()
#   )
#   (fc1): Linear(in_features=1024, out_features=1024, bias=True)
#   (fc2): Linear(in_features=1024, out_features=512, bias=True)
#   (fc3): Linear(in_features=512, out_features=100, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
# )

# %%
class EarlyStopping:
    def __init__(self, patience=7, min_delta=0.0001):
        self.min_delta = min_delta
        self.patience = patience
        self.counter = 0
        self.min_val_loss = float('inf')

    def early_stopper(self, val_loss):
        if val_loss < self.min_val_loss:
            self.min_val_loss = val_loss
            self.counter = 0
        elif val_loss > (self.min_val_loss + self.min_delta):
            self.counter += 1
            if self.counter >= self.patience:
                return True
        return False

# %%
n_epochs = 100

valid_loss_min = np.inf

if not train_on_gpu:
    print('CUDA is not available.  Training on CPU ...')
else:
    print('CUDA is available!  Training on GPU ...')

train_losses = []
val_losses = []
train_accuracies = []
val_accuracies = []
learning_rates = []

ealry_stopper = EarlyStopping()

for epoch in range(1, n_epochs+1):
    train_loss = 0.0
    valid_loss = 0.0

    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        if train_on_gpu:
            data, target = data.cuda(), target.cuda()

        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()

        train_loss += loss.item() * data.size(0)
        
    scheduler.step()

    current_lr = scheduler.get_last_lr()[0]
    learning_rates.append(current_lr)
    print(f"Current LR: {current_lr:.6e}")
    train_acc = calculate_accuracy(model, train_loader, device)
    val_acc = calculate_accuracy(model, val_loader, device)
    train_accuracies.append(train_acc * 100)
    val_accuracies.append(val_acc * 100)
    print(f'Train Accuracy: {train_acc:.4f}, Val Accuracy: {val_acc:.4f}')


    model.eval()
    for batch_idx, (data, target) in enumerate(val_loader):
        if train_on_gpu:
            data, target = data.cuda(), target.cuda()

        output = model(data)
        loss = criterion(output, target)

        valid_loss += loss.item() * data.size(0)

    train_loss = train_loss / len(train_loader.dataset)
    valid_loss = valid_loss / len(val_loader.dataset)

    train_losses.append(train_loss)
    val_losses.append(valid_loss)

    if ealry_stopper.early_stopper(valid_loss):
        print("Stopping Early...")
        break

    print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(
        epoch, train_loss, valid_loss))

    if valid_loss < valid_loss_min:
        print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
            valid_loss_min, valid_loss))
        torch.save(model.state_dict(), 'model.pt')
        valid_loss_min = valid_loss
# Out:
# CUDA is available!  Training on GPU ...
# Current LR: 1.000000e-03
# Train Accuracy: 0.0329, Val Accuracy: 0.0360
# Epoch: 1 	Training Loss: 4.389591 	Validation Loss: 4.235083
# Validation loss decreased (inf --> 4.235083).  Saving model ...
# Current LR: 1.000000e-03
# Train Accuracy: 0.0541, Val Accuracy: 0.0702
# Epoch: 2 	Training Loss: 4.138122 	Validation Loss: 3.887745
# Validation loss decreased (4.235083 --> 3.887745).  Saving model ...
# Current LR: 1.000000e-03
# Train Accuracy: 0.0618, Val Accuracy: 0.0778
# Epoch: 3 	Training Loss: 3.996791 	Validation Loss: 3.795664
# Validation loss decreased (3.887745 --> 3.795664).  Saving model ...
# Current LR: 1.000000e-03
# Train Accuracy: 0.0822, Val Accuracy: 0.0942
# Epoch: 4 	Training Loss: 3.888373 	Validation Loss: 3.815180
# Current LR: 1.000000e-03
# Train Accuracy: 0.1062, Val Accuracy: 0.1226
# Epoch: 5 	Training Loss: 3.795217 	Validation Loss: 3.561043
# Validation loss decreased (3.795664 --> 3.561043).  Saving model ...
# Current LR: 1.000000e-03
# Train Accuracy: 0.1181, Val Accuracy: 0.1496
# Epoch: 6 	Training Loss: 3.691305 	Validation Loss: 3.403354
# Validation loss decreased (3.561043 --> 3.403354).  Saving model ...
# Current LR: 1.000000e-03
# Train Accuracy: 0.1298, Val Accuracy: 0.1498
# Epoch: 7 	Training Loss: 3.619888 	Validation Loss: 3.400118
# Validation loss decreased (3.403354 --> 3.400118).  Saving model ...
# Current LR: 1.000000e-03
# Train Accuracy: 0.1469, Val Accuracy: 0.1782
# Epoch: 8 	Training Loss: 3.537029 	Validation Loss: 3.271609
# Validation loss decreased (3.400118 --> 3.271609).  Saving model ...
# Current LR: 1.000000e-03
# Train Accuracy: 0.1655, Val Accuracy: 0.1822
# Epoch: 9 	Training Loss: 3.468063 	Validation Loss: 3.256565
# Validation loss decreased (3.271609 --> 3.256565).  Saving model ...
# Current LR: 1.000000e-03
# Train Accuracy: 0.1682, Val Accuracy: 0.1920
# Epoch: 10 	Training Loss: 3.388763 	Validation Loss: 3.158869
# Validation loss decreased (3.256565 --> 3.158869).  Saving model ...
# Current LR: 1.000000e-03
# Train Accuracy: 0.1572, Val Accuracy: 0.1650
# Epoch: 11 	Training Loss: 3.313431 	Validation Loss: 3.277138
# Current LR: 1.000000e-03
# Train Accuracy: 0.2049, Val Accuracy: 0.2246
# Epoch: 12 	Training Loss: 3.237866 	Validation Loss: 3.062942
# Validation loss decreased (3.158869 --> 3.062942).  Saving model ...
# Current LR: 1.000000e-03
# Train Accuracy: 0.2131, Val Accuracy: 0.2354
# Epoch: 13 	Training Loss: 3.178117 	Validation Loss: 3.012570
# Validation loss decreased (3.062942 --> 3.012570).  Saving model ...
# Current LR: 1.000000e-03
# Train Accuracy: 0.2404, Val Accuracy: 0.2380
# Epoch: 14 	Training Loss: 3.089039 	Validation Loss: 2.968244
# Validation loss decreased (3.012570 --> 2.968244).  Saving model ...
# Current LR: 1.000000e-03
# Train Accuracy: 0.2633, Val Accuracy: 0.2806
# Epoch: 15 	Training Loss: 3.042216 	Validation Loss: 2.813570
# Validation loss decreased (2.968244 --> 2.813570).  Saving model ...
# Current LR: 1.000000e-03
# Train Accuracy: 0.2394, Val Accuracy: 0.2478
# Epoch: 16 	Training Loss: 2.978121 	Validation Loss: 2.892460
# Current LR: 1.000000e-03
# Train Accuracy: 0.2878, Val Accuracy: 0.3164
# Epoch: 17 	Training Loss: 2.926340 	Validation Loss: 2.634735
# Validation loss decreased (2.813570 --> 2.634735).  Saving model ...
# Current LR: 1.000000e-03
# Train Accuracy: 0.2798, Val Accuracy: 0.2948
# Epoch: 18 	Training Loss: 2.867555 	Validation Loss: 2.710468
# Current LR: 1.000000e-03
# Train Accuracy: 0.3154, Val Accuracy: 0.3342
# Epoch: 19 	Training Loss: 2.815160 	Validation Loss: 2.508461
# Validation loss decreased (2.634735 --> 2.508461).  Saving model ...
# Current LR: 7.000000e-04
# Train Accuracy: 0.3041, Val Accuracy: 0.3194
# Epoch: 20 	Training Loss: 2.760891 	Validation Loss: 2.544044
# Current LR: 7.000000e-04
# Train Accuracy: 0.3287, Val Accuracy: 0.3420
# Epoch: 21 	Training Loss: 2.669213 	Validation Loss: 2.467747
# Validation loss decreased (2.508461 --> 2.467747).  Saving model ...
# Current LR: 7.000000e-04
# Train Accuracy: 0.3547, Val Accuracy: 0.3682
# Epoch: 22 	Training Loss: 2.622545 	Validation Loss: 2.383474
# Validation loss decreased (2.467747 --> 2.383474).  Saving model ...
# Current LR: 7.000000e-04
# Train Accuracy: 0.3490, Val Accuracy: 0.3528
# Epoch: 23 	Training Loss: 2.594625 	Validation Loss: 2.406421
# Current LR: 7.000000e-04
# Train Accuracy: 0.3639, Val Accuracy: 0.3690
# Epoch: 24 	Training Loss: 2.559862 	Validation Loss: 2.349131
# Validation loss decreased (2.383474 --> 2.349131).  Saving model ...
# Current LR: 7.000000e-04
# Train Accuracy: 0.3787, Val Accuracy: 0.3876
# Epoch: 25 	Training Loss: 2.524444 	Validation Loss: 2.326141
# Validation loss decreased (2.349131 --> 2.326141).  Saving model ...
# Current LR: 7.000000e-04
# Train Accuracy: 0.3660, Val Accuracy: 0.3678
# Epoch: 26 	Training Loss: 2.488836 	Validation Loss: 2.364163
# Current LR: 7.000000e-04
# Train Accuracy: 0.3734, Val Accuracy: 0.3798
# Epoch: 27 	Training Loss: 2.460776 	Validation Loss: 2.325566
# Validation loss decreased (2.326141 --> 2.325566).  Saving model ...
# Current LR: 7.000000e-04
# Train Accuracy: 0.4017, Val Accuracy: 0.4142
# Epoch: 28 	Training Loss: 2.421323 	Validation Loss: 2.162715
# Validation loss decreased (2.325566 --> 2.162715).  Saving model ...
# Current LR: 7.000000e-04
# Train Accuracy: 0.3886, Val Accuracy: 0.3834
# Epoch: 29 	Training Loss: 2.405731 	Validation Loss: 2.266465
# Current LR: 7.000000e-04
# Train Accuracy: 0.3872, Val Accuracy: 0.3834
# Epoch: 30 	Training Loss: 2.362236 	Validation Loss: 2.259467
# Current LR: 7.000000e-04
# Train Accuracy: 0.4209, Val Accuracy: 0.4206
# Epoch: 31 	Training Loss: 2.339964 	Validation Loss: 2.154557
# Validation loss decreased (2.162715 --> 2.154557).  Saving model ...
# Current LR: 7.000000e-04
# Train Accuracy: 0.4312, Val Accuracy: 0.4464
# Epoch: 32 	Training Loss: 2.311885 	Validation Loss: 2.064157
# Validation loss decreased (2.154557 --> 2.064157).  Saving model ...
# Current LR: 7.000000e-04
# Train Accuracy: 0.4139, Val Accuracy: 0.4102
# Epoch: 33 	Training Loss: 2.294318 	Validation Loss: 2.171750
# Current LR: 7.000000e-04
# Train Accuracy: 0.4315, Val Accuracy: 0.4178
# Epoch: 34 	Training Loss: 2.257532 	Validation Loss: 2.127187
# Current LR: 7.000000e-04
# Train Accuracy: 0.4405, Val Accuracy: 0.4416
# Epoch: 35 	Training Loss: 2.234186 	Validation Loss: 2.056742
# Validation loss decreased (2.064157 --> 2.056742).  Saving model ...
# Current LR: 7.000000e-04
# Train Accuracy: 0.4288, Val Accuracy: 0.4288
# Epoch: 36 	Training Loss: 2.210112 	Validation Loss: 2.113823
# Current LR: 7.000000e-04
# Train Accuracy: 0.4658, Val Accuracy: 0.4590
# Epoch: 37 	Training Loss: 2.184409 	Validation Loss: 2.003654
# Validation loss decreased (2.056742 --> 2.003654).  Saving model ...
# Current LR: 7.000000e-04
# Train Accuracy: 0.4646, Val Accuracy: 0.4630
# Epoch: 38 	Training Loss: 2.159601 	Validation Loss: 1.950847
# Validation loss decreased (2.003654 --> 1.950847).  Saving model ...
# Current LR: 7.000000e-04
# Train Accuracy: 0.4712, Val Accuracy: 0.4738
# Epoch: 39 	Training Loss: 2.138140 	Validation Loss: 1.939798
# Validation loss decreased (1.950847 --> 1.939798).  Saving model ...
# Current LR: 4.900000e-04
# Train Accuracy: 0.4887, Val Accuracy: 0.4786
# Epoch: 40 	Training Loss: 2.106685 	Validation Loss: 1.880165
# Validation loss decreased (1.939798 --> 1.880165).  Saving model ...
# Current LR: 4.900000e-04
# Train Accuracy: 0.5105, Val Accuracy: 0.4944
# Epoch: 41 	Training Loss: 2.047966 	Validation Loss: 1.819769
# Validation loss decreased (1.880165 --> 1.819769).  Saving model ...
# Current LR: 4.900000e-04
# Train Accuracy: 0.5125, Val Accuracy: 0.5086
# Epoch: 42 	Training Loss: 2.030234 	Validation Loss: 1.802657
# Validation loss decreased (1.819769 --> 1.802657).  Saving model ...
# Current LR: 4.900000e-04
# Train Accuracy: 0.5179, Val Accuracy: 0.5138
# Epoch: 43 	Training Loss: 2.006511 	Validation Loss: 1.767879
# Validation loss decreased (1.802657 --> 1.767879).  Saving model ...
# Current LR: 4.900000e-04
# Train Accuracy: 0.5269, Val Accuracy: 0.5250
# Epoch: 44 	Training Loss: 1.983023 	Validation Loss: 1.734315
# Validation loss decreased (1.767879 --> 1.734315).  Saving model ...
# Current LR: 4.900000e-04
# Train Accuracy: 0.5265, Val Accuracy: 0.5158
# Epoch: 45 	Training Loss: 1.967793 	Validation Loss: 1.779455
# Current LR: 4.900000e-04
# Train Accuracy: 0.5156, Val Accuracy: 0.4990
# Epoch: 46 	Training Loss: 1.944364 	Validation Loss: 1.806352
# Current LR: 4.900000e-04
# Train Accuracy: 0.5264, Val Accuracy: 0.5124
# Epoch: 47 	Training Loss: 1.942614 	Validation Loss: 1.773592
# Current LR: 4.900000e-04
# Train Accuracy: 0.5343, Val Accuracy: 0.5270
# Epoch: 48 	Training Loss: 1.913704 	Validation Loss: 1.712065
# Validation loss decreased (1.734315 --> 1.712065).  Saving model ...
# Current LR: 4.900000e-04
# Train Accuracy: 0.5251, Val Accuracy: 0.5080
# Epoch: 49 	Training Loss: 1.911893 	Validation Loss: 1.792654
# Current LR: 4.900000e-04
# Train Accuracy: 0.5253, Val Accuracy: 0.5052
# Epoch: 50 	Training Loss: 1.884291 	Validation Loss: 1.834262
# Current LR: 4.900000e-04
# Train Accuracy: 0.5485, Val Accuracy: 0.5274
# Epoch: 51 	Training Loss: 1.871786 	Validation Loss: 1.708223
# Validation loss decreased (1.712065 --> 1.708223).  Saving model ...
# Current LR: 4.900000e-04
# Train Accuracy: 0.5576, Val Accuracy: 0.5442
# Epoch: 52 	Training Loss: 1.856272 	Validation Loss: 1.660138
# Validation loss decreased (1.708223 --> 1.660138).  Saving model ...
# Current LR: 4.900000e-04
# Train Accuracy: 0.5439, Val Accuracy: 0.5186
# Epoch: 53 	Training Loss: 1.841046 	Validation Loss: 1.719625
# Current LR: 4.900000e-04
# Train Accuracy: 0.5510, Val Accuracy: 0.5440
# Epoch: 54 	Training Loss: 1.828022 	Validation Loss: 1.649649
# Validation loss decreased (1.660138 --> 1.649649).  Saving model ...
# Current LR: 4.900000e-04
# Train Accuracy: 0.5503, Val Accuracy: 0.5440
# Epoch: 55 	Training Loss: 1.803786 	Validation Loss: 1.657981
# Current LR: 4.900000e-04
# Train Accuracy: 0.5542, Val Accuracy: 0.5548
# Epoch: 56 	Training Loss: 1.799547 	Validation Loss: 1.604860
# Validation loss decreased (1.649649 --> 1.604860).  Saving model ...
# Current LR: 4.900000e-04
# Train Accuracy: 0.5784, Val Accuracy: 0.5596
# Epoch: 57 	Training Loss: 1.784226 	Validation Loss: 1.594039
# Validation loss decreased (1.604860 --> 1.594039).  Saving model ...
# Current LR: 4.900000e-04
# Train Accuracy: 0.5818, Val Accuracy: 0.5516
# Epoch: 58 	Training Loss: 1.775646 	Validation Loss: 1.625500
# Current LR: 4.900000e-04
# Train Accuracy: 0.5906, Val Accuracy: 0.5730
# Epoch: 59 	Training Loss: 1.759627 	Validation Loss: 1.546316
# Validation loss decreased (1.594039 --> 1.546316).  Saving model ...
# Current LR: 3.430000e-04
# Train Accuracy: 0.5825, Val Accuracy: 0.5634
# Epoch: 60 	Training Loss: 1.742517 	Validation Loss: 1.586773
# Current LR: 3.430000e-04
# Train Accuracy: 0.5939, Val Accuracy: 0.5678
# Epoch: 61 	Training Loss: 1.699914 	Validation Loss: 1.560921
# Current LR: 3.430000e-04
# Train Accuracy: 0.6074, Val Accuracy: 0.5820
# Epoch: 62 	Training Loss: 1.689645 	Validation Loss: 1.506624
# Validation loss decreased (1.546316 --> 1.506624).  Saving model ...
# Current LR: 3.430000e-04
# Train Accuracy: 0.6100, Val Accuracy: 0.5788
# Epoch: 63 	Training Loss: 1.666104 	Validation Loss: 1.513326
# Current LR: 3.430000e-04
# Train Accuracy: 0.5992, Val Accuracy: 0.5758
# Epoch: 64 	Training Loss: 1.669153 	Validation Loss: 1.543148
# Current LR: 3.430000e-04
# Train Accuracy: 0.6038, Val Accuracy: 0.5740
# Epoch: 65 	Training Loss: 1.648640 	Validation Loss: 1.547340
# Current LR: 3.430000e-04
# Train Accuracy: 0.6104, Val Accuracy: 0.5862
# Epoch: 66 	Training Loss: 1.641225 	Validation Loss: 1.494205
# Validation loss decreased (1.506624 --> 1.494205).  Saving model ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[39], line 23
#      20 valid_loss = 0.0
#      22 model.train()
# ---> 23 for batch_idx, (data, target) in enumerate(train_loader):
#      24     if train_on_gpu:
#      25         data, target = data.cuda(), target.cuda()
#
# File c:\Users\trevo\CSCI611_Summer25_Trevor_Streng\final_project\venv\Lib\site-packages\torch\utils\data\dataloader.py:733, in _BaseDataLoaderIter.__next__(self)
#     730 if self._sampler_iter is None:
#     731     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     732     self._reset()  # type: ignore[call-arg]
# --> 733 data = self._next_data()
#     734 self._num_yielded += 1
#     735 if (
#     736     self._dataset_kind == _DatasetKind.Iterable
#     737     and self._IterableDataset_len_called is not None
#     738     and self._num_yielded > self._IterableDataset_len_called
#     739 ):
#
# File c:\Users\trevo\CSCI611_Summer25_Trevor_Streng\final_project\venv\Lib\site-packages\torch\utils\data\dataloader.py:789, in _SingleProcessDataLoaderIter._next_data(self)
#     787 def _next_data(self):
#     788     index = self._next_index()  # may raise StopIteration
# --> 789     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     790     if self._pin_memory:
#     791         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File c:\Users\trevo\CSCI611_Summer25_Trevor_Streng\final_project\venv\Lib\site-packages\torch\utils\data\_utils\fetch.py:52, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
# ---> 52         data = [self.dataset[idx] for idx in possibly_batched_index]
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
#
# Cell In[30], line 14, in MappedImageFolder.__getitem__(self, index)
#      12 image = self.loader(path)
#      13 if self.transform is not None:
# ---> 14     image = self.transform(image)
#      16 folder_name = path.split(os.sep)[-2]
#      17 label = self.folder_to_label[folder_name]
#
# File c:\Users\trevo\CSCI611_Summer25_Trevor_Streng\final_project\venv\Lib\site-packages\torchvision\transforms\transforms.py:95, in Compose.__call__(self, img)
#      93 def __call__(self, img):
#      94     for t in self.transforms:
# ---> 95         img = t(img)
#      96     return img
#
# File c:\Users\trevo\CSCI611_Summer25_Trevor_Streng\final_project\venv\Lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File c:\Users\trevo\CSCI611_Summer25_Trevor_Streng\final_project\venv\Lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File c:\Users\trevo\CSCI611_Summer25_Trevor_Streng\final_project\venv\Lib\site-packages\torchvision\transforms\transforms.py:1280, in ColorJitter.forward(self, img)
#    1278         img = F.adjust_saturation(img, saturation_factor)
#    1279     elif fn_id == 3 and hue_factor is not None:
# -> 1280         img = F.adjust_hue(img, hue_factor)
#    1282 return img
#
# File c:\Users\trevo\CSCI611_Summer25_Trevor_Streng\final_project\venv\Lib\site-packages\torchvision\transforms\functional.py:968, in adjust_hue(img, hue_factor)
#     966     _log_api_usage_once(adjust_hue)
#     967 if not isinstance(img, torch.Tensor):
# --> 968     return F_pil.adjust_hue(img, hue_factor)
#     970 return F_t.adjust_hue(img, hue_factor)
#
# File c:\Users\trevo\CSCI611_Summer25_Trevor_Streng\final_project\venv\Lib\site-packages\torchvision\transforms\_functional_pil.py:117, in adjust_hue(img, hue_factor)
#     113 np_h += np.int32(hue_factor * 255).astype(np.uint8)
#     115 h = Image.fromarray(np_h, "L")
# --> 117 img = Image.merge("HSV", (h, s, v)).convert(input_mode)
#     118 return img
#
# File c:\Users\trevo\CSCI611_Summer25_Trevor_Streng\final_project\venv\Lib\site-packages\PIL\Image.py:1152, in Image.convert(self, mode, matrix, dither, palette, colors)
#    1149     dither = Dither.FLOYDSTEINBERG
#    1151 try:
# -> 1152     im = self.im.convert(mode, dither)
#    1153 except ValueError:
#    1154     try:
#    1155         # normalize source image and try again
#
# KeyboardInterrupt:

# %%
# Loss Plot
plt.figure(figsize=(10, 5))
plt.plot(train_losses, label='Training Loss')
plt.plot(val_losses, label='Validation Loss')
# plt.plot(learning_rates, label='Learning Rate', linestyle='dashed')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training vs. Validation Loss')
plt.legend()
plt.grid(True)
plt.show()

# Accuracy Plot
plt.figure(figsize=(10, 5))
plt.plot(train_accuracies, label='Training Accuracy')
plt.plot(val_accuracies, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy in %')
plt.title('Training vs. Validation Loss')
plt.legend()
plt.grid(True)
plt.show()

# Validation Accuracy vs Loss
plt.figure(figsize=(10, 5))
plt.plot(val_losses, label='Validation Loss')
plt.plot(val_accuracies, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy in %')
plt.title('Validation Loss vs. Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %%
model.load_state_dict(torch.load('model.pt'))
# Out:
# <All keys matched successfully>

# %%
test_loss = 0.0
classes_correct = list(0. for i in range(100))
classes_total = list(0. for i in range(100))

model.eval()

classes = test_data.classes

for data, target in test_loader:
    if train_on_gpu:
        data, target = data.cuda(), target.cuda()

    output = model(data)
    loss = criterion(output, target)

    test_loss += loss.item() * data.size(0)

    _, pred = torch.max(output, 1)
    correct_tensor = pred.eq(target.data.view_as(pred))
    correct = np.squeeze(correct_tensor.cpu().numpy())

    for i in range(len(target)):
        label = target.data[i]
        classes_correct[label] += correct[i].item()
        classes_total[label] += 1

test_loss = test_loss / len(test_loader.dataset)
print('Test Loss: {:.6f}\n'.format(test_loss))

for i in range(100):
    if classes_total[i] > 0:
        print('Test Accuracy of %5s: %2d%% (%2d/%2d)' % (
            classes[i], 100 * classes_correct[i] / classes_total[i],
            np.sum(classes_correct[i]), np.sum(classes_total[i])))
    else:
        print('Test Accuracy of %5s: N/A (no training examples)' % (classes[i]))

print('\nTest Accuracy (Overall): %2d%% (%2d/%2d)' % (
    100. * np.sum(classes_correct) / np.sum(classes_total),
    np.sum(classes_correct), np.sum(classes_total)))
# Out:
# Test Loss: 1.515515
#
# Test Accuracy of     0: 76% (38/50)
# Test Accuracy of     1: 12% ( 6/50)
# Test Accuracy of    10: 64% (32/50)
# Test Accuracy of    11: 60% (30/50)
# Test Accuracy of    12: 82% (41/50)
# Test Accuracy of    13: 22% (11/50)
# Test Accuracy of    14: 80% (40/50)
# Test Accuracy of    15: 30% (15/50)
# Test Accuracy of    16: 36% (18/50)
# Test Accuracy of    17: 32% (16/50)
# Test Accuracy of    18: 52% (26/50)
# Test Accuracy of    19: 68% (34/50)
# Test Accuracy of     2: 38% (19/50)
# Test Accuracy of    20: 98% (49/50)
# Test Accuracy of    21: 44% (22/50)
# Test Accuracy of    22: 20% (10/50)
# Test Accuracy of    23: 52% (26/50)
# Test Accuracy of    24: 58% (29/50)
# Test Accuracy of    25: 24% (12/50)
# Test Accuracy of    26: 72% (36/50)
# Test Accuracy of    27: 68% (34/50)
# Test Accuracy of    28: 70% (35/50)
# Test Accuracy of    29: 46% (23/50)
# Test Accuracy of     3: 50% (25/50)
# Test Accuracy of    30: 38% (19/50)
# Test Accuracy of    31: 62% (31/50)
# Test Accuracy of    32: 70% (35/50)
# Test Accuracy of    33: 70% (35/50)
# Test Accuracy of    34: 42% (21/50)
# Test Accuracy of    35: 32% (16/50)
# Test Accuracy of    36: 70% (35/50)
# Test Accuracy of    37: 72% (36/50)
# Test Accuracy of    38: 68% (34/50)
# Test Accuracy of    39: 74% (37/50)
# Test Accuracy of     4: 94% (47/50)
# Test Accuracy of    40: 64% (32/50)
# Test Accuracy of    41: 34% (17/50)
# Test Accuracy of    42: 50% (25/50)
# Test Accuracy of    43: 88% (44/50)
# Test Accuracy of    44: 70% (35/50)
# Test Accuracy of    45: 38% (19/50)
# Test Accuracy of    46: 44% (22/50)
# Test Accuracy of    47: 46% (23/50)
# Test Accuracy of    48: 50% (25/50)
# Test Accuracy of    49: 50% (25/50)
# Test Accuracy of     5: 90% (45/50)
# Test Accuracy of    50: 84% (42/50)
# Test Accuracy of    51: 82% (41/50)
# Test Accuracy of    52: 34% (17/50)
# Test Accuracy of    53: 68% (34/50)
# Test Accuracy of    54: 64% (32/50)
# Test Accuracy of    55: 48% (24/50)
# Test Accuracy of    56: 64% (32/50)
# Test Accuracy of    57: 80% (40/50)
# Test Accuracy of    58: 70% (35/50)
# Test Accuracy of    59: 70% (35/50)
# Test Accuracy of     6: 66% (33/50)
# Test Accuracy of    60: 72% (36/50)
# Test Accuracy of    61: 88% (44/50)
# Test Accuracy of    62: 64% (32/50)
# Test Accuracy of    63: 44% (22/50)
# Test Accuracy of    64: 86% (43/50)
# Test Accuracy of    65: 38% (19/50)
# Test Accuracy of    66: 58% (29/50)
# Test Accuracy of    67: 52% (26/50)
# Test Accuracy of    68: 52% (26/50)
# Test Accuracy of    69: 62% (31/50)
# Test Accuracy of     7: 44% (22/50)
# Test Accuracy of    70: 76% (38/50)
# Test Accuracy of    71: 54% (27/50)
# Test Accuracy of    72: 46% (23/50)
# Test Accuracy of    73: 42% (21/50)
# Test Accuracy of    74: 30% (15/50)
# Test Accuracy of    75: 40% (20/50)
# Test Accuracy of    76: 36% (18/50)
# Test Accuracy of    77: 40% (20/50)
# Test Accuracy of    78: 54% (27/50)
# Test Accuracy of    79: 66% (33/50)
# Test Accuracy of     8: 76% (38/50)
# Test Accuracy of    80: 68% (34/50)
# Test Accuracy of    81: 34% (17/50)
# Test Accuracy of    82: 64% (32/50)
# Test Accuracy of    83: 84% (42/50)
# Test Accuracy of    84: 68% (34/50)
# Test Accuracy of    85: 70% (35/50)
# Test Accuracy of    86: 50% (25/50)
# Test Accuracy of    87: 48% (24/50)
# Test Accuracy of    88: 50% (25/50)
# Test Accuracy of    89: 48% (24/50)
# Test Accuracy of     9: 54% (27/50)
# Test Accuracy of    90: 12% ( 6/50)
# Test Accuracy of    91: 58% (29/50)
# Test Accuracy of    92: 36% (18/50)
# Test Accuracy of    93: 70% (35/50)
# Test Accuracy of    94: 54% (27/50)
# Test Accuracy of    95: 48% (24/50)
# Test Accuracy of    96: 56% (28/50)
# Test Accuracy of    97: 90% (45/50)
# Test Accuracy of    98: 54% (27/50)
# Test Accuracy of    99: 54% (27/50)
#
# Test Accuracy (Overall): 56% (2845/5000)

# %%
dataiter = iter(test_loader)
images, labels = next(dataiter)
# images = images.numpy()

if train_on_gpu:
    images = images.cuda()

output = model(images)
_, preds_tensor = torch.max(output, 1)
preds = preds_tensor.cpu().numpy()

fig = plt.figure(figsize=(12, 6))
for idx in np.arange(12):
    ax = fig.add_subplot(4, 3, idx+1, xticks=[], yticks=[])
    imshow(images[idx].cpu())
    ax.set_title(f'Predicted: {classes[preds[idx]]}\nActual: {classes[labels[idx]]}', color=('green' if preds[idx] == labels[idx] else 'red'))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.558952..1.82].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.40222222..1.7154248].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.558952..1.82].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.558952..1.7415688].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.558952..1.7142857].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.558952..1.5567226].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.5418272..1.82].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.40222222..1.82].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.558952..1.82].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.55038965..1.7142857].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.5332649..1.5645175].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.5003501..1.82].
