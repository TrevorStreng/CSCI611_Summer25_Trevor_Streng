# %% [markdown]
# # Fruit Classification CNN

# %%
import torch
import numpy as np

# check if CUDA is available
train_on_gpu = torch.cuda.is_available()

if not train_on_gpu:
    print('CUDA is not available.  Training on CPU ...')
else:
    print('CUDA is available!  Training on GPU ...')
# Out:
# CUDA is available!  Training on GPU ...

# %%
# Organizing the classes correctly
import pandas as pd
folder_to_class = {}
test_df = pd.read_csv('Fruit_dataset/test.csv')
val_df = pd.read_csv('Fruit_dataset/val.csv')

val_classes = ['']
test_classes = ['']

for i in range(len(test_df)):
    folder_loc = test_df.iloc[i]['image:FILE'].split('/')[1]
    if not folder_loc: break
    if folder_loc != test_classes[-1]:
        test_classes.append(folder_loc)
        
for i in range(len(val_df)):
    folder_loc = val_df.iloc[i]['image:FILE'].split('/')[1]
    if folder_loc != val_classes[-1]:
        val_classes.append(folder_loc)

val_classes = val_classes[1:]
test_classes = test_classes[1:]
folder_to_class = dict(zip(val_classes, test_classes))

print(folder_to_class)
# Out:
# {'oil_palm': '28', 'hog_plum': '3', 'apricot': '93', 'sugar_apple': '58', 'rambutan': '80', 'yellow_plum': '49', 'pineapple': '43', 'dewberry': '71', 'plumcot': '23', 'ambarella': '8', 'grenadilla': '46', 'elderberry': '98', 'barbadine': '87', 'horned_melon': '39', 'chico': '61', 'mock_strawberry': '92', 'cashew': '44', 'finger_lime': '9', 'apple': '12', 'eggplant': '38', 'pawpaw': '0', 'chokeberry': '55', 'jamaica_cherry': '18', 'grapefruit': '88', 'santol': '86', 'chenet': '95', 'salak': '1', 'indian_strawberry': '16', 'cherimoya': '47', 'otaheite_apple': '7', 'dragonfruit': '15', 'raspberry': '27', 'mangosteen': '63', 'yali_pear': '60', 'taxus_baccata': '76', 'coconut': '19', 'guava': '41', 'black_mullberry': '83', 'durian': '73', 'ackee': '2', 'olive': '26', 'mandarine': '70', 'black_berry': '29', 'acerola': '32', 'jaboticaba': '24', 'fig': '82', 'langsat': '78', 'redcurrant': '77', 'gooseberry': '13', 'camu_camu': '11', 'barberry': '69', 'rose_hip': '67', 'jalapeno': '65', 'brazil_nut': '89', 'damson': '31', 'acai': '53', 'prikly_pear': '37', 'morinda': '59', 'sea_buckthorn': '74', 'avocado': '40', 'strawberry_guava': '96', 'jackfruit': '20', 'greengage': '36', 'cupuacu': '5', 'longan': '68', 'passion_fruit': '91', 'feijoa': '97', 'betel_nut': '22', 'kaffir_lime': '81', 'sapodilla': '45', 'cempedak': '17', 'hawthorn': '57', 'mango': '21', 'malay_apple': '52', 'cranberry': '34', 'jocote': '84', 'cluster_fig': '66', 'corn_kernel': '6', 'kumquat': '99', 'rose_leaf_bramble': '54', 'jujube': '35', 'grape': '33', 'pea': '56', 'papaya': '14', 'bitter_gourd': '48', 'ugli_fruit': '64', 'jambul': '10', 'mabolo': '85', 'abiu': '62', 'quince': '90', 'custard_apple': '75', 'medlar': '72', 'mountain_soursop': '42', 'banana': '79', 'goumi': '51', 'hard_kiwi': '94', 'pomegranate': '25', 'white_currant': '30', 'lablab': '4', 'emblic': '50'}

# %%
import os
# from PIL import Image

# root_dir = 'Fruit_dataset/train1'

# max_width, max_height = float(0), float(0)
# min_width, min_height = float('inf'), float('inf')

# for subdir, _, files in os.walk(root_dir):
#     for file in files:
#         if file.lower().endswith(('.png', '.jpg', '.jpeg')):
#             img_path = os.path.join(subdir, file)
#             with Image.open(img_path) as img:
#                 w, h = img.size
#                 if w > max_width:
#                     max_width = w
#                 if h > max_height:
#                     max_height = h
#                 if w < min_width:
#                     min_width = w
#                 if h < min_height:
#                     min_height = h

# print(f"Smallest width: {min_width}, Smallest height: {min_height}")
# print(f"Biggest width: {max_width}, Biggest height: {max_height}")
test_path = "./Fruit_dataset/test1"

# List all subfolders (classes)
class_folders = [name for name in os.listdir(test_path) if os.path.isdir(os.path.join(test_path, name))]

print(f"Number of classes: {len(class_folders)}")
# Out:
# Number of classes: 100

# %%
from torchvision import datasets, transforms

from torchvision.datasets import ImageFolder

class MappedImageFolder(ImageFolder):
    def __init__(self, root, correct_order, transform=None):
        super().__init__(root, transform=transform)
        self.folder_to_label = {folder: correct_order.index(folder) for folder in self.classes}
        
    def __getitem__(self, index):
        path, _ = self.samples[index]
        image = self.loader(path)
        if self.transform is not None:
            image = self.transform(image)
        
        folder_name = path.split(os.sep)[-2]
        label = self.folder_to_label[folder_name]
        
        return image, label

batch_size = 50

train_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomVerticalFlip(p=0.3),
    transforms.RandomRotation(degrees=30),
    # transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    # transforms.Pad(10),
    # transforms.CenterCrop((128, 128)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    # transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])

transform = transforms.Compose([
    transforms.Resize((224, 224)),
    # transforms.Pad(10),
    # transforms.CenterCrop((128, 128)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    # transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])

# train_data = datasets.ImageFolder(root='Fruit_dataset/train1', transform=train_transform)
train_data = MappedImageFolder('Fruit_dataset/train1', val_classes, transform=train_transform)
train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, shuffle=True, pin_memory=True)
folder_to_correct_label = {folder: val_classes.index(folder) for folder in train_data.classes}
print(train_loader.dataset.classes)
print(folder_to_correct_label)

# val_data = datasets.ImageFolder(root='Fruit_dataset/val1', transform=transform)
val_data = MappedImageFolder('Fruit_dataset/val1', val_classes, transform=transform)
val_loader = torch.utils.data.DataLoader(val_data, batch_size=batch_size, shuffle=True, pin_memory=True)
folder_to_correct_label = {folder: val_classes.index(folder) for folder in val_data.classes}
print(len(val_data))

# test_data = datasets.ImageFolder(root='Fruit_dataset/test1', transform=transform)
test_data = MappedImageFolder('Fruit_dataset/test1', test_classes, transform=transform)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=batch_size, shuffle=True, pin_memory=True)
folder_to_correct_label = {folder: test_classes.index(folder) for folder in test_data.classes}
print(len(test_data))

# train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, shuffle=True)
# val_loader = torch.utils.data.DataLoader(val_data, batch_size=batch_size, shuffle=True)
# test_loader = torch.utils.data.DataLoader(test_data, batch_size=batch_size, shuffle=True)
# Out:
# ['abiu', 'acai', 'acerola', 'ackee', 'ambarella', 'apple', 'apricot', 'avocado', 'banana', 'barbadine', 'barberry', 'betel_nut', 'bitter_gourd', 'black_berry', 'black_mullberry', 'brazil_nut', 'camu_camu', 'cashew', 'cempedak', 'chenet', 'cherimoya', 'chico', 'chokeberry', 'cluster_fig', 'coconut', 'corn_kernel', 'cranberry', 'cupuacu', 'custard_apple', 'damson', 'dewberry', 'dragonfruit', 'durian', 'eggplant', 'elderberry', 'emblic', 'feijoa', 'fig', 'finger_lime', 'gooseberry', 'goumi', 'grape', 'grapefruit', 'greengage', 'grenadilla', 'guava', 'hard_kiwi', 'hawthorn', 'hog_plum', 'horned_melon', 'indian_strawberry', 'jaboticaba', 'jackfruit', 'jalapeno', 'jamaica_cherry', 'jambul', 'jocote', 'jujube', 'kaffir_lime', 'kumquat', 'lablab', 'langsat', 'longan', 'mabolo', 'malay_apple', 'mandarine', 'mango', 'mangosteen', 'medlar', 'mock_strawberry', 'morinda', 'mountain_soursop', 'oil_palm', 'olive', 'otaheite_apple', 'papaya', 'passion_fruit', 'pawpaw', 'pea', 'pineapple', 'plumcot', 'pomegranate', 'prikly_pear', 'quince', 'rambutan', 'raspberry', 'redcurrant', 'rose_hip', 'rose_leaf_bramble', 'salak', 'santol', 'sapodilla', 'sea_buckthorn', 'strawberry_guava', 'sugar_apple', 'taxus_baccata', 'ugli_fruit', 'white_currant', 'yali_pear', 'yellow_plum']
# {'abiu': 88, 'acai': 55, 'acerola': 43, 'ackee': 39, 'ambarella': 9, 'apple': 18, 'apricot': 2, 'avocado': 59, 'banana': 93, 'barbadine': 12, 'barberry': 50, 'betel_nut': 67, 'bitter_gourd': 84, 'black_berry': 42, 'black_mullberry': 37, 'brazil_nut': 53, 'camu_camu': 49, 'cashew': 16, 'cempedak': 70, 'chenet': 25, 'cherimoya': 28, 'chico': 14, 'chokeberry': 21, 'cluster_fig': 76, 'coconut': 35, 'corn_kernel': 77, 'cranberry': 74, 'cupuacu': 63, 'custard_apple': 90, 'damson': 54, 'dewberry': 7, 'dragonfruit': 30, 'durian': 38, 'eggplant': 19, 'elderberry': 11, 'emblic': 99, 'feijoa': 66, 'fig': 45, 'finger_lime': 17, 'gooseberry': 48, 'goumi': 94, 'grape': 81, 'grapefruit': 23, 'greengage': 62, 'grenadilla': 10, 'guava': 36, 'hard_kiwi': 95, 'hawthorn': 71, 'hog_plum': 1, 'horned_melon': 13, 'indian_strawberry': 27, 'jaboticaba': 44, 'jackfruit': 61, 'jalapeno': 52, 'jamaica_cherry': 22, 'jambul': 86, 'jocote': 75, 'jujube': 80, 'kaffir_lime': 68, 'kumquat': 78, 'lablab': 98, 'langsat': 46, 'longan': 64, 'mabolo': 87, 'malay_apple': 73, 'mandarine': 41, 'mango': 72, 'mangosteen': 32, 'medlar': 91, 'mock_strawberry': 15, 'morinda': 57, 'mountain_soursop': 92, 'oil_palm': 0, 'olive': 40, 'otaheite_apple': 29, 'papaya': 83, 'passion_fruit': 65, 'pawpaw': 20, 'pea': 82, 'pineapple': 6, 'plumcot': 8, 'pomegranate': 96, 'prikly_pear': 56, 'quince': 89, 'rambutan': 4, 'raspberry': 31, 'redcurrant': 47, 'rose_hip': 51, 'rose_leaf_bramble': 79, 'salak': 26, 'santol': 24, 'sapodilla': 69, 'sea_buckthorn': 58, 'strawberry_guava': 60, 'sugar_apple': 3, 'taxus_baccata': 34, 'ugli_fruit': 85, 'white_currant': 97, 'yali_pear': 33, 'yellow_plum': 5}
# 5000
# 5000

# %%
import matplotlib.pyplot as plt

def imshow(img):
  img = img / 2 + 0.5
  plt.imshow(np.transpose(img, (1, 2, 0)))

# %%
classes = train_data.classes

dataiter = iter(train_loader)

images, labels = next(dataiter)
images = images.numpy() # convert images to numpy for display

images, labels = next(dataiter)

fig = plt.figure(figsize=(12, 6))
for idx in range(8):
  ax = fig.add_subplot(2, 4, idx+1, xticks=[], yticks=[])
  imshow(images[idx])
  ax.set_title(classes[labels[idx]])

# from PIL import Image
# import matplotlib.pyplot as plt
# import os

# # Get a list of image file paths
# image_paths = []
# for subdir, _, files in os.walk('Fruit_dataset/train1'):
#     for file in files:
#         if file.lower().endswith(('.png', '.jpg', '.jpeg')):
#             image_paths.append(os.path.join(subdir, file))

# # Display the first 8 images
# fig = plt.figure(figsize=(12, 6))
# for idx, img_path in enumerate(image_paths[:8]):
#     img = Image.open(img_path)
#     ax = fig.add_subplot(2, 4, idx+1, xticks=[], yticks=[])
#     plt.imshow(img)
#     ax.set_title(os.path.basename(os.path.dirname(img_path)))
# plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.558952..1.8025708].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.558952..1.82].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.558952..1.82].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.558952..1.82].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.558952..1.7938564].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.558952..1.82].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.558952..1.7415688].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.558952..1.732854].

# %%
# import torch.nn as nn
# import torch.nn.functional as F

# class Net(nn.Module):
#     def __init__(self):
#         super(Net, self).__init__()
#         self.conv1 = nn.Conv2d(3, 32, kernel_size=3, padding=1)
#         self.bn1 = nn.BatchNorm2d(32)

#         self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
#         self.bn2 = nn.BatchNorm2d(64)

#         # self.conv3 = nn.Conv2d(64, 64, kernel_size=3, padding=1)
#         # self.bn3 = nn.BatchNorm2d(64)

#         self.conv3 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
#         self.bn3 = nn.BatchNorm2d(128)

#         # self.conv5 = nn.Conv2d(128, 128, kernel_size=3, padding=1)
#         # self.bn5 = nn.BatchNorm2d(128)

#         # self.conv6 = nn.Conv2d(128, 128, kernel_size=3, padding=1)
#         # self.bn6 = nn.BatchNorm2d(128)

#         self.conv4 = nn.Conv2d(128, 256, kernel_size=3, padding=1)
#         self.bn4 = nn.BatchNorm2d(256)
        
#         # self.conv8 = nn.Conv2d(256, 256, kernel_size=3, padding=1)
#         # self.bn8 = nn.BatchNorm2d(256)

#         # self.conv9 = nn.Conv2d(256, 256, kernel_size=3, padding=1)
#         # self.bn9 = nn.BatchNorm2d(256)

#         self.conv5 = nn.Conv2d(256, 512, kernel_size=3, padding=1)
#         self.bn5 = nn.BatchNorm2d(512)

#         # self.conv11 = nn.Conv2d(512, 512, kernel_size=3, padding=1)
#         # self.bn11 = nn.BatchNorm2d(512)

#         # self.conv12 = nn.Conv2d(512, 512, kernel_size=3, padding=1)
#         # self.bn12 = nn.BatchNorm2d(512)

#         # self.conv13 = nn.Conv2d(512, 1024, kernel_size=3, padding=1)
#         # self.bn13 = nn.BatchNorm2d(1024)

#         # self.conv14 = nn.Conv2d(1024, 1024, kernel_size=3, padding=1)
#         # self.bn14 = nn.BatchNorm2d(1024)

#         self.pool = nn.MaxPool2d(kernel_size=2, stride=2)

#         self.fc1 = nn.Linear(512 * 14 * 14, 512)
#         self.fc2 = nn.Linear(512, 256)
#         self.fc3 = nn.Linear(256, 100)

#         self.dropout = nn.Dropout(0.2)

#     def forward(self, x):
#         x = self.bn1(F.relu(self.conv1(x)))

#         x = self.pool(x)
        
#         x = self.bn2(F.relu(self.conv2(x)))
#         # x = self.bn3(F.relu(self.conv3(x)))

#         x = self.pool(x)

#         x = self.bn3(F.relu(self.conv3(x)))
#         # x = self.bn5(F.relu(self.conv5(x)))
#         # x = self.bn6(F.relu(self.conv6(x)))

#         x = self.pool(x)

#         x = self.bn4(F.relu(self.conv4(x)))
#         # x = self.bn8(F.relu(self.conv8(x)))
#         # x = self.bn9(F.relu(self.conv9(x)))

#         x = self.pool(x)

#         x = self.bn5(F.relu(self.conv5(x)))
#         # x = self.bn11(F.relu(self.conv11(x)))
#         # x = self.bn12(F.relu(self.conv12(x)))

#         # x = self.pool(x)

#         # x = self.bn13(F.relu(self.conv13(x)))
#         # x = self.bn14(F.relu(self.conv14(x)))

#         # x = x.view(-1, 256 * 14 * 14)
#         x = x.view(x.size(0), -1)

#         x = F.relu(self.fc1(x))
#         x = F.relu(self.fc2(x))
#         x = self.fc3(x)
#         return x
    
# model = Net()
# print(model)

# if(train_on_gpu):
#   model.cuda()

# %%
import torch.nn as nn
import torch.nn.functional as F

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()

        num_blocks = 4
        num_params = 64
        # img_size = 224

        self.blocks = nn.ModuleList()

        for idx in range(num_blocks):
            if idx == 0:
                self.blocks.append(
                    nn.Conv2d(3, num_params, kernel_size=3, stride=1, padding=1)
                )
            else:
                num_params *= 2
                self.blocks.append(
                    nn.Conv2d(int(num_params / 2), num_params, kernel_size=3, stride=1, padding=1)
                )

            self.blocks.append(
                    nn.Conv2d(num_params, num_params, kernel_size=3, stride=1, padding=1)
            )
            self.blocks.append(nn.BatchNorm2d(num_params))
            self.blocks.append(nn.ReLU())
            if idx < num_blocks - 1:
                self.blocks.append(nn.MaxPool2d(2, 2))
                # img_size //= 2
            else:
                self.blocks.append(nn.AdaptiveAvgPool2d((1, 1)))

            self.blocks.append(nn.ReLU())


        self.avg_pool = nn.AdaptiveAvgPool2d((1, 1))
        self.fc1 = nn.Linear(num_params, 1024)
        self.fc2 = nn.Linear(1024, 512)
        self.fc3 = nn.Linear(512, len(classes))

        self.dropout = nn.Dropout(0.25)

    def forward(self, x):
        for block in self.blocks:
            x = block(x)

        x = x.view(x.size(0), -1)
        x = F.relu(self.fc1(x))
        x = self.dropout(x)
        x = F.relu(self.fc2(x))
        x = self.dropout(x)
        x = self.fc3(x)

        return x





model = Net()
print(model)

if(train_on_gpu):
  model.cuda()
# Out:
# Net(
#   (blocks): ModuleList(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): ReLU()
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (9): ReLU()
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (12): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (13): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (14): ReLU()
#     (15): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (16): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (17): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (18): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (19): ReLU()
#     (20): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (21): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): ReLU()
#   )
#   (fc1): Linear(in_features=50176, out_features=1024, bias=True)
#   (fc2): Linear(in_features=1024, out_features=512, bias=True)
#   (fc3): Linear(in_features=512, out_features=100, bias=True)
# )

# %%
import torch.optim as optim
from torch.amp import autocast, GradScaler
criterion = nn.CrossEntropyLoss()

optimizer = optim.Adam(model.parameters(), lr=0.001)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=25, gamma=0.5)
scaler = GradScaler('cuda' if train_on_gpu else 'cpu')

# %%
def calculate_accuracy(model, dataloader, device):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for inputs, labels in dataloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    return correct / total

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# Net(
#   (blocks): ModuleList(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): ReLU()
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (9): ReLU()
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (12): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (13): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (14): ReLU()
#     (15): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (16): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (17): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (18): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (19): ReLU()
#     (20): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (21): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): ReLU()
#   )
#   (fc1): Linear(in_features=50176, out_features=1024, bias=True)
#   (fc2): Linear(in_features=1024, out_features=512, bias=True)
#   (fc3): Linear(in_features=512, out_features=100, bias=True)
# )

# %%
class EarlyStopping:
    def __init__(self, patience=7, min_delta=0.0001):
        self.min_delta = min_delta
        self.patience = patience
        self.counter = 0
        self.min_val_loss = float('inf')

    def early_stopper(self, val_loss):
        if val_loss < self.min_val_loss:
            self.min_val_loss = val_loss
            self.counter = 0
        elif val_loss > (self.min_val_loss + self.min_delta):
            self.counter += 1
            if self.counter >= self.patience:
                return True
        return False

# %%
n_epochs = 50

valid_loss_min = np.inf

if not train_on_gpu:
    print('CUDA is not available.  Training on CPU ...')
else:
    print('CUDA is available!  Training on GPU ...')

train_losses = []
val_losses = []
train_accuracies = []
val_accuracies = []
learning_rates = []

ealry_stopper = EarlyStopping()

for epoch in range(1, n_epochs+1):
    train_loss = 0.0
    valid_loss = 0.0

    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        if train_on_gpu:
            data, target = data.cuda(), target.cuda()

        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()

        train_loss += loss.item() * data.size(0)
        
    scheduler.step()

    current_lr = scheduler.get_last_lr()[0]
    learning_rates.append(current_lr)
    print(f"Current LR: {current_lr:.6e}")
    train_acc = calculate_accuracy(model, train_loader, device)
    val_acc = calculate_accuracy(model, val_loader, device)
    train_accuracies.append(train_acc * 100)
    val_accuracies.append(val_acc * 100)
    print(f'Train Accuracy: {train_acc:.4f}, Val Accuracy: {val_acc:.4f}')


    model.eval()
    for batch_idx, (data, target) in enumerate(val_loader):
        if train_on_gpu:
            data, target = data.cuda(), target.cuda()

        output = model(data)
        loss = criterion(output, target)

        valid_loss += loss.item() * data.size(0)

    train_loss = train_loss / len(train_loader.dataset)
    valid_loss = valid_loss / len(val_loader.dataset)

    train_losses.append(train_loss)
    val_losses.append(valid_loss)

    if ealry_stopper.early_stopper(valid_loss):
        print("Stopping Early...")
        break

    print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(
        epoch, train_loss, valid_loss))

    if valid_loss < valid_loss_min:
        print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
            valid_loss_min, valid_loss))
        torch.save(model.state_dict(), 'model.pt')
        valid_loss_min = valid_loss
# Out:
# CUDA is available!  Training on GPU ...
# Current LR: 1.000000e-03
# Train Accuracy: 0.0222, Val Accuracy: 0.0178
# Epoch: 1 	Training Loss: 4.708764 	Validation Loss: 4.393726
# Validation loss decreased (inf --> 4.393726).  Saving model ...
# Current LR: 1.000000e-03
# Train Accuracy: 0.0704, Val Accuracy: 0.0686
# Epoch: 2 	Training Loss: 4.088983 	Validation Loss: 3.867756
# Validation loss decreased (4.393726 --> 3.867756).  Saving model ...
# Current LR: 1.000000e-03
# Train Accuracy: 0.0984, Val Accuracy: 0.0988
# Epoch: 3 	Training Loss: 3.667259 	Validation Loss: 3.599733
# Validation loss decreased (3.867756 --> 3.599733).  Saving model ...
# Current LR: 1.000000e-03
# Train Accuracy: 0.1220, Val Accuracy: 0.1184
# Epoch: 4 	Training Loss: 3.512385 	Validation Loss: 3.458977
# Validation loss decreased (3.599733 --> 3.458977).  Saving model ...
# Current LR: 1.000000e-03
# Train Accuracy: 0.1271, Val Accuracy: 0.1280
# Epoch: 5 	Training Loss: 3.421559 	Validation Loss: 3.416892
# Validation loss decreased (3.458977 --> 3.416892).  Saving model ...
# Current LR: 1.000000e-03
# Train Accuracy: 0.1486, Val Accuracy: 0.1434
# Epoch: 6 	Training Loss: 3.348765 	Validation Loss: 3.327491
# Validation loss decreased (3.416892 --> 3.327491).  Saving model ...
# Current LR: 1.000000e-03
# Train Accuracy: 0.1595, Val Accuracy: 0.1540
# Epoch: 7 	Training Loss: 3.281112 	Validation Loss: 3.287732
# Validation loss decreased (3.327491 --> 3.287732).  Saving model ...
# Current LR: 1.000000e-03
# Train Accuracy: 0.1809, Val Accuracy: 0.1680
# Epoch: 8 	Training Loss: 3.213319 	Validation Loss: 3.180305
# Validation loss decreased (3.287732 --> 3.180305).  Saving model ...
# Current LR: 1.000000e-03
# Train Accuracy: 0.2003, Val Accuracy: 0.1880
# Epoch: 9 	Training Loss: 3.146289 	Validation Loss: 3.116271
# Validation loss decreased (3.180305 --> 3.116271).  Saving model ...
# Current LR: 5.000000e-04
# Train Accuracy: 0.1997, Val Accuracy: 0.1940
# Epoch: 10 	Training Loss: 3.073182 	Validation Loss: 3.113751
# Validation loss decreased (3.116271 --> 3.113751).  Saving model ...
# Current LR: 5.000000e-04
# Train Accuracy: 0.2276, Val Accuracy: 0.2176
# Epoch: 11 	Training Loss: 2.911070 	Validation Loss: 2.990020
# Validation loss decreased (3.113751 --> 2.990020).  Saving model ...
# Current LR: 5.000000e-04
# Train Accuracy: 0.2632, Val Accuracy: 0.2496
# Epoch: 12 	Training Loss: 2.843546 	Validation Loss: 2.848011
# Validation loss decreased (2.990020 --> 2.848011).  Saving model ...
# Current LR: 5.000000e-04
# Train Accuracy: 0.2720, Val Accuracy: 0.2590
# Epoch: 13 	Training Loss: 2.785151 	Validation Loss: 2.806205
# Validation loss decreased (2.848011 --> 2.806205).  Saving model ...
# Current LR: 5.000000e-04
# Train Accuracy: 0.2691, Val Accuracy: 0.2574
# Epoch: 14 	Training Loss: 2.729060 	Validation Loss: 2.820473
# Current LR: 5.000000e-04
# Train Accuracy: 0.3039, Val Accuracy: 0.2824
# Epoch: 15 	Training Loss: 2.672049 	Validation Loss: 2.696609
# Validation loss decreased (2.806205 --> 2.696609).  Saving model ...
# Current LR: 5.000000e-04
# Train Accuracy: 0.3166, Val Accuracy: 0.2976
# Epoch: 16 	Training Loss: 2.620284 	Validation Loss: 2.634201
# Validation loss decreased (2.696609 --> 2.634201).  Saving model ...
# Current LR: 5.000000e-04
# Train Accuracy: 0.3083, Val Accuracy: 0.2774
# Epoch: 17 	Training Loss: 2.559364 	Validation Loss: 2.712799
# Current LR: 5.000000e-04
# Train Accuracy: 0.3306, Val Accuracy: 0.3130
# Epoch: 18 	Training Loss: 2.534599 	Validation Loss: 2.585578
# Validation loss decreased (2.634201 --> 2.585578).  Saving model ...
# Current LR: 5.000000e-04
# Train Accuracy: 0.3494, Val Accuracy: 0.3288
# Epoch: 19 	Training Loss: 2.478048 	Validation Loss: 2.518877
# Validation loss decreased (2.585578 --> 2.518877).  Saving model ...
# Current LR: 2.500000e-04
# Train Accuracy: 0.3527, Val Accuracy: 0.3228
# Epoch: 20 	Training Loss: 2.433899 	Validation Loss: 2.519247
# Current LR: 2.500000e-04
# Train Accuracy: 0.3751, Val Accuracy: 0.3446
# Epoch: 21 	Training Loss: 2.332297 	Validation Loss: 2.435953
# Validation loss decreased (2.518877 --> 2.435953).  Saving model ...
# Current LR: 2.500000e-04
# Train Accuracy: 0.3939, Val Accuracy: 0.3578
# Epoch: 22 	Training Loss: 2.295601 	Validation Loss: 2.362547
# Validation loss decreased (2.435953 --> 2.362547).  Saving model ...
# Current LR: 2.500000e-04
# Train Accuracy: 0.3934, Val Accuracy: 0.3644
# Epoch: 23 	Training Loss: 2.270020 	Validation Loss: 2.359388
# Validation loss decreased (2.362547 --> 2.359388).  Saving model ...
# Current LR: 2.500000e-04
# Train Accuracy: 0.3969, Val Accuracy: 0.3622
# Epoch: 24 	Training Loss: 2.249764 	Validation Loss: 2.357919
# Validation loss decreased (2.359388 --> 2.357919).  Saving model ...
# Current LR: 2.500000e-04
# Train Accuracy: 0.3885, Val Accuracy: 0.3652
# Epoch: 25 	Training Loss: 2.227065 	Validation Loss: 2.378037
# Current LR: 2.500000e-04
# Train Accuracy: 0.4064, Val Accuracy: 0.3728
# Epoch: 26 	Training Loss: 2.203096 	Validation Loss: 2.331538
# Validation loss decreased (2.357919 --> 2.331538).  Saving model ...
# Current LR: 2.500000e-04
# Train Accuracy: 0.4153, Val Accuracy: 0.3778
# Epoch: 27 	Training Loss: 2.187998 	Validation Loss: 2.303790
# Validation loss decreased (2.331538 --> 2.303790).  Saving model ...
# Current LR: 2.500000e-04
# Train Accuracy: 0.4192, Val Accuracy: 0.3788
# Epoch: 28 	Training Loss: 2.174331 	Validation Loss: 2.286918
# Validation loss decreased (2.303790 --> 2.286918).  Saving model ...
# Current LR: 2.500000e-04
# Train Accuracy: 0.4179, Val Accuracy: 0.3808
# Epoch: 29 	Training Loss: 2.153746 	Validation Loss: 2.278982
# Validation loss decreased (2.286918 --> 2.278982).  Saving model ...
# Current LR: 1.250000e-04
# Train Accuracy: 0.4247, Val Accuracy: 0.3858
# Epoch: 30 	Training Loss: 2.132271 	Validation Loss: 2.263609
# Validation loss decreased (2.278982 --> 2.263609).  Saving model ...
# Current LR: 1.250000e-04
# Train Accuracy: 0.4422, Val Accuracy: 0.4066
# Epoch: 31 	Training Loss: 2.067914 	Validation Loss: 2.198700
# Validation loss decreased (2.263609 --> 2.198700).  Saving model ...
# Current LR: 1.250000e-04
# Train Accuracy: 0.4440, Val Accuracy: 0.3980
# Epoch: 32 	Training Loss: 2.058243 	Validation Loss: 2.195763
# Validation loss decreased (2.198700 --> 2.195763).  Saving model ...
# Current LR: 1.250000e-04
# Train Accuracy: 0.4420, Val Accuracy: 0.3990
# Epoch: 33 	Training Loss: 2.042616 	Validation Loss: 2.188057
# Validation loss decreased (2.195763 --> 2.188057).  Saving model ...
# Current LR: 1.250000e-04
# Train Accuracy: 0.4474, Val Accuracy: 0.4106
# Epoch: 34 	Training Loss: 2.030256 	Validation Loss: 2.174263
# Validation loss decreased (2.188057 --> 2.174263).  Saving model ...
# Current LR: 1.250000e-04
# Train Accuracy: 0.4518, Val Accuracy: 0.4152
# Epoch: 35 	Training Loss: 2.017549 	Validation Loss: 2.167240
# Validation loss decreased (2.174263 --> 2.167240).  Saving model ...
# Current LR: 1.250000e-04
# Train Accuracy: 0.4529, Val Accuracy: 0.4150
# Epoch: 36 	Training Loss: 2.004581 	Validation Loss: 2.159504
# Validation loss decreased (2.167240 --> 2.159504).  Saving model ...
# Current LR: 1.250000e-04
# Train Accuracy: 0.4593, Val Accuracy: 0.4190
# Epoch: 37 	Training Loss: 1.996576 	Validation Loss: 2.139745
# Validation loss decreased (2.159504 --> 2.139745).  Saving model ...

# %%
# Loss Plot
plt.figure(figsize=(10, 5))
plt.plot(train_losses, label='Training Loss')
plt.plot(val_losses, label='Validation Loss')
plt.plot(learning_rates, label='Learning Rate', linestyle='dashed')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training vs. Validation Loss')
plt.legend()
plt.grid(True)
plt.show()

# Accuracy Plot
plt.figure(figsize=(10, 5))
plt.plot(train_accuracies, label='Training Accuracy')
plt.plot(val_accuracies, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy in %')
plt.title('Training vs. Validation Loss')
plt.legend()
plt.grid(True)
plt.show()

# Validation Accuracy vs Loss
plt.figure(figsize=(10, 5))
plt.plot(val_losses, label='Validation Loss')
plt.plot(val_accuracies, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy in %')
plt.title('Validation Loss vs. Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %%
model.load_state_dict(torch.load('model.pt'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 model.load_state_dict(torch.load('model.pt'))
#
# NameError: name 'model' is not defined

# %%
test_loss = 0.0
classes_correct = list(0. for i in range(100))
classes_total = list(0. for i in range(100))

model.eval()

classes = test_data.classes

for data, target in test_loader:
    if train_on_gpu:
        data, target = data.cuda(), target.cuda()

    output = model(data)
    loss = criterion(output, target)

    test_loss += loss.item() * data.size(0)

    _, pred = torch.max(output, 1)
    correct_tensor = pred.eq(target.data.view_as(pred))
    correct = np.squeeze(correct_tensor.cpu().numpy())

    for i in range(len(target)):
        label = target.data[i]
        classes_correct[label] += correct[i].item()
        classes_total[label] += 1

test_loss = test_loss / len(test_loader.dataset)
print('Test Loss: {:.6f}\n'.format(test_loss))

for i in range(100):
    if classes_total[i] > 0:
        print('Test Accuracy of %5s: %2d%% (%2d/%2d)' % (
            classes[i], 100 * classes_correct[i] / classes_total[i],
            np.sum(classes_correct[i]), np.sum(classes_total[i])))
    else:
        print('Test Accuracy of %5s: N/A (no training examples)' % (classes[i]))

print('\nTest Accuracy (Overall): %2d%% (%2d/%2d)' % (
    100. * np.sum(classes_correct) / np.sum(classes_total),
    np.sum(classes_correct), np.sum(classes_total)))
# Out:
# Test Loss: 2.051350
#
# Test Accuracy of     0: 70% (35/50)
# Test Accuracy of     1:  2% ( 1/50)
# Test Accuracy of    10: 54% (27/50)
# Test Accuracy of    11: 36% (18/50)
# Test Accuracy of    12: 78% (39/50)
# Test Accuracy of    13: 28% (14/50)
# Test Accuracy of    14: 76% (38/50)
# Test Accuracy of    15: 28% (14/50)
# Test Accuracy of    16: 24% (12/50)
# Test Accuracy of    17: 24% (12/50)
# Test Accuracy of    18: 28% (14/50)
# Test Accuracy of    19: 56% (28/50)
# Test Accuracy of     2: 28% (14/50)
# Test Accuracy of    20: 84% (42/50)
# Test Accuracy of    21: 20% (10/50)
# Test Accuracy of    22: 34% (17/50)
# Test Accuracy of    23: 24% (12/50)
# Test Accuracy of    24: 24% (12/50)
# Test Accuracy of    25: 36% (18/50)
# Test Accuracy of    26: 58% (29/50)
# Test Accuracy of    27: 40% (20/50)
# Test Accuracy of    28: 44% (22/50)
# Test Accuracy of    29: 40% (20/50)
# Test Accuracy of     3: 20% (10/50)
# Test Accuracy of    30: 42% (21/50)
# Test Accuracy of    31: 50% (25/50)
# Test Accuracy of    32: 70% (35/50)
# Test Accuracy of    33: 56% (28/50)
# Test Accuracy of    34: 36% (18/50)
# Test Accuracy of    35: 38% (19/50)
# Test Accuracy of    36: 68% (34/50)
# Test Accuracy of    37: 74% (37/50)
# Test Accuracy of    38: 54% (27/50)
# Test Accuracy of    39: 72% (36/50)
# Test Accuracy of     4: 88% (44/50)
# Test Accuracy of    40: 48% (24/50)
# Test Accuracy of    41: 38% (19/50)
# Test Accuracy of    42: 42% (21/50)
# Test Accuracy of    43: 70% (35/50)
# Test Accuracy of    44: 70% (35/50)
# Test Accuracy of    45: 26% (13/50)
# Test Accuracy of    46: 50% (25/50)
# Test Accuracy of    47: 50% (25/50)
# Test Accuracy of    48: 38% (19/50)
# Test Accuracy of    49: 52% (26/50)
# Test Accuracy of     5: 64% (32/50)
# Test Accuracy of    50: 38% (19/50)
# Test Accuracy of    51: 76% (38/50)
# Test Accuracy of    52: 12% ( 6/50)
# Test Accuracy of    53: 66% (33/50)
# Test Accuracy of    54: 40% (20/50)
# Test Accuracy of    55: 32% (16/50)
# Test Accuracy of    56: 54% (27/50)
# Test Accuracy of    57: 54% (27/50)
# Test Accuracy of    58: 68% (34/50)
# Test Accuracy of    59: 40% (20/50)
# Test Accuracy of     6: 32% (16/50)
# Test Accuracy of    60: 60% (30/50)
# Test Accuracy of    61: 86% (43/50)
# Test Accuracy of    62: 52% (26/50)
# Test Accuracy of    63: 32% (16/50)
# Test Accuracy of    64: 80% (40/50)
# Test Accuracy of    65: 24% (12/50)
# Test Accuracy of    66: 76% (38/50)
# Test Accuracy of    67: 48% (24/50)
# Test Accuracy of    68: 38% (19/50)
# Test Accuracy of    69: 40% (20/50)
# Test Accuracy of     7: 36% (18/50)
# Test Accuracy of    70: 54% (27/50)
# Test Accuracy of    71: 70% (35/50)
# Test Accuracy of    72: 46% (23/50)
# Test Accuracy of    73: 42% (21/50)
# Test Accuracy of    74: 22% (11/50)
# Test Accuracy of    75: 28% (14/50)
# Test Accuracy of    76: 32% (16/50)
# Test Accuracy of    77: 38% (19/50)
# Test Accuracy of    78: 40% (20/50)
# Test Accuracy of    79: 58% (29/50)
# Test Accuracy of     8: 50% (25/50)
# Test Accuracy of    80: 58% (29/50)
# Test Accuracy of    81: 20% (10/50)
# Test Accuracy of    82: 44% (22/50)
# Test Accuracy of    83: 72% (36/50)
# Test Accuracy of    84: 58% (29/50)
# Test Accuracy of    85: 48% (24/50)
# Test Accuracy of    86: 58% (29/50)
# Test Accuracy of    87: 48% (24/50)
# Test Accuracy of    88: 34% (17/50)
# Test Accuracy of    89: 46% (23/50)
# Test Accuracy of     9: 24% (12/50)
# Test Accuracy of    90: 12% ( 6/50)
# Test Accuracy of    91: 32% (16/50)
# Test Accuracy of    92: 30% (15/50)
# Test Accuracy of    93: 48% (24/50)
# Test Accuracy of    94: 42% (21/50)
# Test Accuracy of    95: 36% (18/50)
# Test Accuracy of    96: 48% (24/50)
# Test Accuracy of    97: 66% (33/50)
# Test Accuracy of    98: 44% (22/50)
# Test Accuracy of    99: 70% (35/50)
#
# Test Accuracy (Overall): 46% (2327/5000)

# %%
dataiter = iter(test_loader)
images, labels = next(dataiter)
# images = images.numpy()

if train_on_gpu:
    images = images.cuda()

output = model(images)
_, preds_tensor = torch.max(output, 1)
preds = preds_tensor.cpu().numpy()

fig = plt.figure(figsize=(12, 6))
for idx in np.arange(50):
    ax = fig.add_subplot(10, 5, idx+1, xticks=[], yticks=[])
    imshow(images[idx].cpu())
    ax.set_title(f'Predicted: {classes[preds[idx]]}\nActual: {classes[labels[idx]]}', color=('green' if preds[idx] == labels[idx] else 'red'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 8
#       5 if train_on_gpu:
#       6     images = images.cuda()
# ----> 8 output = model(images)
#       9 _, preds_tensor = torch.max(output, 1)
#      10 preds = preds_tensor.cpu().numpy()
#
# NameError: name 'model' is not defined
